# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\my project\datafile.csv')

# %%
df.head()
# Out:
#         Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0        Rural  2013   January                 107.5          106.3  108.1
# 1        Urban  2013   January                 110.5          109.1  113.0
# 2  Rural+Urban  2013   January                 108.4          107.3  110.0
# 3        Rural  2013  February                 109.2          108.7  110.2
# 4        Urban  2013  February                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      NaN
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 3              105.4          106.7   104.0       102.4  ...      NaN
# 4              104.0          103.5   103.1       104.9  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# ...

# %%
df.dropna(inplace=True)

# %%
# Convert numerical columns to numeric data type, replacing non-numeric values with NaN
numeric_columns = df.columns[3:-1]  # Select columns with numeric data
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# Group the data by sector and calculate the mean for each sector
grouped_data = df.groupby('Sector').mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8844\382711758.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby('Sector').mean()

# %%
# Plot the average values for each sector
grouped_data.plot(kind='bar', figsize=(25,15))
plt.xlabel('Sector')
plt.ylabel('Average Value')
plt.title('Average Values by Sector')
plt.legend(loc='upper right')
plt.show()

# %%
# Convert Year column to datetime type
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# %%
# Plot multiple visualizations sector-wise
plt.figure(figsize=(12, 6))

# %%
# Sector-wise line plot
plt.figure(figsize=(15,10))
sns.lineplot(data=df, x='Year', y='General index', hue='Sector')
plt.xlabel('Year')
plt.ylabel('General Index')
plt.title('General Index by Sector')
# Out:
# Text(0.5, 1.0, 'General Index by Sector')

# %%
# Sector-wise bar plot
plt.figure(figsize=(15,10))
sns.barplot(data=df, x='Sector', y='General index', hue='Year')
plt.xlabel('Sector')
plt.ylabel('General Index')
plt.title('General Index by Sector and Year')
plt.tight_layout()
plt.show()

# %%
df.head(5)
# Out:
#         Sector       Year     Month  Cereals and products  Meat and fish  \
# 1        Urban 2013-01-01   January                 110.5          109.1
# 2  Rural+Urban 2013-01-01   January                 108.4          107.3
# 4        Urban 2013-01-01  February                 112.9          112.9
# 5  Rural+Urban 2013-01-01  February                 110.4          110.2
# 7        Urban 2013-01-01     March                 113.9          111.4
#
#      Egg  Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 1  113.0              103.6          103.4   102.3       102.9  ...    100.3
# 2  110.0              104.4          105.1   103.2       102.2  ...    100.3
# 4  116.9              104.0          103.5   103.1       104.9  ...    100.4
# 5  112.8              104.9          105.5   103.6       103.2  ...    100.4
# 7  113.2              104.3          102.7   104.9       103.8  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()

# %%
df1 = df.copy()

# %%
df['Month'] = lbl.fit_transform(df1['Month'])
df.head(3)
# Out:
#         Sector       Year  Month  Cereals and products  Meat and fish    Egg  \
# 1        Urban 2013-01-01      4                 110.5          109.1  113.0
# 2  Rural+Urban 2013-01-01      4                 108.4          107.3  110.0
# 4        Urban 2013-01-01      3                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 4              104.0          103.5   103.1       104.9  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# 1           105.4                         104.8   104.1
# 2           105.5                         104.8   104.0
# 4           105.7                         105.2   104.7
#
#    Transport and communication  Recreation and amusement  Education  \
# 1                        103.2                     102.9      103.5
# ...

# %%
df1.columns
# Out:
# Index(['Sector', 'Year', 'Month', 'Cereals and products', 'Meat and fish',
#        'Egg', 'Milk and products', 'Oils and fats', 'Fruits', 'Vegetables',
#        'Pulses and products', 'Sugar and Confectionery', 'Spices',
#        'Non-alcoholic beverages', 'Prepared meals, snacks, sweets etc.',
#        'Food and beverages', 'Pan, tobacco and intoxicants', 'Clothing',
#        'Footwear', 'Clothing and footwear', 'Housing', 'Fuel and light',
#        'Household goods and services', 'Health', 'Transport and communication',
#        'Recreation and amusement', 'Education', 'Personal care and effects',
#        'Miscellaneous', 'General index'],
#       dtype='object')

# %%
cols = ['Cereals and products', 'Meat and fish',
       'Egg', 'Milk and products', 'Oils and fats', 'Fruits', 'Vegetables',
       'Pulses and products', 'Sugar and Confectionery', 'Spices',
       'Non-alcoholic beverages', 'Prepared meals, snacks, sweets etc.',
       'Food and beverages', 'Pan, tobacco and intoxicants', 'Clothing',
       'Footwear', 'Clothing and footwear', 'Housing', 'Fuel and light',
       'Household goods and services', 'Health', 'Transport and communication',
       'Recreation and amusement', 'Education', 'Personal care and effects',
       'Miscellaneous', 'General index']

# %%
plt.figure(figsize=(15,5))
plt.plot(df1['Month'],df1[cols[0]],'o')
plt.ylabel(cols[0])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df1['Month'],df1[cols[1]],'o')
plt.ylabel(cols[1])
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x='Month', y=cols[1], data=df1)
plt.xlabel('Month')
plt.ylabel(cols[1])
plt.title(f'Seaborn Bar Plot for {cols[1]} over Months')
plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df1.groupby(['Year', 'Month'])['Cereals and products'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(1,len(pivot_df), figsize=(50, 15), subplot_kw=dict(aspect="equal"))
    for i, (year, data) in enumerate(pivot_df.iterrows()):
        ax = axes[i]
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular

    plt.suptitle('Pie Chart for Cereals and products Distribution by Month (Year-wise)')
    plt.show()

# %%
df['Year'] = df['Year'].dt.year

# %%
df.head()
# Out:
#         Sector  Year  Month  Cereals and products  Meat and fish    Egg  \
# 1        Urban  2013      4                 110.5          109.1  113.0
# 2  Rural+Urban  2013      4                 108.4          107.3  110.0
# 4        Urban  2013      3                 112.9          112.9  116.9
# 5  Rural+Urban  2013      3                 110.4          110.2  112.8
# 7        Urban  2013      7                 113.9          111.4  113.2
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 4              104.0          103.5   103.1       104.9  ...    100.4
# 5              104.9          105.5   103.6       103.2  ...    100.4
# 7              104.3          102.7   104.9       103.8  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# ...

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Cereals and products'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(1,len(pivot_df), figsize=(50, 15), subplot_kw=dict(aspect="equal"))
    for i, (year, data) in enumerate(pivot_df.iterrows()):
        ax = axes[i]
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular

    plt.suptitle('Pie Chart for Cereals and products Distribution by Month (Year-wise)')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Cereals and products'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Meat and fish'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Meat and fish products sector')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Egg'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Meat and fish products sector')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Milk and products'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Milk and products products sector')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Oils and fats'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Oils and fats products sector')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Fruits'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Fruits products sector')
    plt.show()

# %%
# Aggregate data for each year and month
total_cereals_by_year_month = df.groupby(['Year', 'Month'])['Vegetables'].sum()

# Check if the DataFrame is empty
if total_cereals_by_year_month.empty:
    print("No data available for the given columns.")
else:
    # Reshape the DataFrame for better visualization
    pivot_df = total_cereals_by_year_month.unstack().fillna(0)

    # Get the number of rows and columns for subplots
    num_rows = (len(pivot_df) // 4) + (len(pivot_df) % 4 > 0)  # Calculate the number of rows needed
    num_cols = min(4, len(pivot_df))  # 3 columns or the total number of years, whichever is smaller

    # Plot a pie chart for each year with specified figsize
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,15))
    for (year, data), ax in zip(pivot_df.iterrows(), axes.flatten()):
        ax.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
        ax.set_title(f'Year {year}')
        ax.set_aspect('equal')  # To ensure pie charts are circular
    plt.axis('off')
    plt.subplots_adjust(top=0.75)
    plt.title('Yearwise growth distribution Vegetables products sector')
    plt.show()
